# %%
source("utilities.R")
library(ggplot2)
library(scales)

# LOAD DATA
Italy2_mgs <- read.delim("data/level4ec_and_pathway/mgs_level4ec_relab_unstratified/Italy2_mgs_level4ec_relab_unstratified.tsv", row.names = 1, check.names = FALSE)
Italy2_mgs <- Italy2_mgs[!rownames(Italy2_mgs) %in% c("UNMAPPED","UNGROUPED"),]
Italy2_ssms <- read.delim("data/level4ec_and_pathway/ssms_level4ec_relab_unstratified/Italy2_500K_level4ec_relab_unstratified.tsv", row.names = 1, check.names = FALSE)
Italy2_ssms <- Italy2_ssms[!rownames(Italy2_ssms) %in% c("UNMAPPED","UNGROUPED"),]
Italy1_mgs <- read.delim("data/level4ec_and_pathway/mgs_level4ec_relab_unstratified/Italy1_mgs_level4ec_relab_unstratified.tsv", row.names = 1, check.names = FALSE)
Italy1_mgs <- Italy1_mgs[!rownames(Italy1_mgs) %in% c("UNMAPPED","UNGROUPED"),]
Italy1_ssms <- read.delim("data/level4ec_and_pathway/ssms_level4ec_relab_unstratified/Italy1_500K_level4ec_relab_unstratified.tsv", row.names = 1, check.names = FALSE)
Italy1_ssms <- Italy1_ssms[!rownames(Italy1_ssms) %in% c("UNMAPPED","UNGROUPED"),]
Austria_mgs <- read.delim("data/level4ec_and_pathway/mgs_level4ec_relab_unstratified/Austria_mgs_level4ec_relab_unstratified.tsv", row.names = 1, check.names = FALSE)
Austria_mgs <- Austria_mgs[!rownames(Austria_mgs) %in% c("UNMAPPED","UNGROUPED"),]
Austria_ssms <- read.delim("data/level4ec_and_pathway/ssms_level4ec_relab_unstratified/Austria_500K_level4ec_relab_unstratified.tsv", row.names = 1, check.names = FALSE)
Austria_ssms <- Austria_ssms[!rownames(Austria_ssms) %in% c("UNMAPPED","UNGROUPED"),]

Italy2_mgs <- Italy2_mgs[order(rownames(Italy2_mgs)), ]
Italy1_mgs <- Italy1_mgs[order(rownames(Italy1_mgs)), ]
Austria_mgs <- Austria_mgs[order(rownames(Austria_mgs)), ]

Italy2_ssms <- Italy2_ssms[order(rownames(Italy2_ssms)), ]
Italy1_ssms <- Italy1_ssms[order(rownames(Italy1_ssms)), ]
Austria_ssms <- Austria_ssms[order(rownames(Austria_ssms)), ]

# fastcclasso
fastcclasso_80 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_fastcclasso_80.csv", row.names = 1, sep = '\t')
fastcclasso_90 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_fastcclasso_90.csv", row.names = 1, sep = '\t')
fastcclasso_95 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_fastcclasso_95.csv", row.names = 1, sep = '\t')    
fastcclasso_99 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_fastcclasso_99.csv", row.names = 1, sep = '\t')

list_fastcclasso_para <- list(
    fastcclasso_80 = fastcclasso_80,
    fastcclasso_90 = fastcclasso_90,
    fastcclasso_95 = fastcclasso_95,
    fastcclasso_99 = fastcclasso_99,
    Italy2_ssms = Italy2_ssms
)

# genie3

genie3_80 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_genie3_80.csv", row.names = 1, sep = '\t')
genie3_90 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_genie3_90.csv", row.names = 1, sep = '\t')
genie3_95 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_genie3_95.csv", row.names = 1, sep = '\t')    
genie3_99 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_genie3_99.csv", row.names = 1, sep = '\t')

list_genie3_para <- list(
  genie3_80 = genie3_80,
  genie3_90 = genie3_90,
  genie3_95 = genie3_95,
  genie3_99 = genie3_99,
  Italy2_ssms = Italy2_ssms
)

# spearman
spearman_80 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_spearman_80.csv", row.names = 1, sep = '\t')
spearman_90 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_spearman_90.csv", row.names = 1, sep = '\t')
spearman_95 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_spearman_95.csv", row.names = 1, sep = '\t')    

list_spearman_para <- list(
  spearman_80 = spearman_80,
  spearman_90 = spearman_90,
  spearman_95 = spearman_95,
  Italy2_ssms = Italy2_ssms
) 

# sparcc
sparcc_50 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_sparcc_50.csv", row.names = 1, sep = '\t')
sparcc_70 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_sparcc_70.csv", row.names = 1, sep = '\t')
sparcc_90 <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_sparcc_90.csv", row.names = 1, sep = '\t')

list_sparcc_para <- list(
  sparcc_50 = sparcc_50,
   sparcc_70 = sparcc_70,
   sparcc_90 = sparcc_90,
   Italy2_ssms = Italy2_ssms
)

# spieceasi
spieceasi <- read.csv("data/imputed_ec/parameter_test/predicted_level4ec_spiec_Austriaasref_Italy2_spieceasi.csv", row.names = 1, sep = '\t')

# %%
#
fastcclasso_para_spearman <- compute_similarity(Italy2_mgs, list_fastcclasso_para, method = "spearman")
genie3_para_spearman <- compute_similarity(Italy2_mgs, list_genie3_para, method = "spearman")
spearman_para_spearman <- compute_similarity(Italy2_mgs, list_spearman_para, method = "spearman")
sparcc_para_spearman <- compute_similarity(Italy2_mgs, list_sparcc_para, method = "spearman")

fastcclasso_para_jaccard <- compute_similarity(Italy2_mgs, list_fastcclasso_para, method = "jaccard")  
genie3_para_jaccard <- compute_similarity(Italy2_mgs, list_genie3_para, method = "jaccard")
spearman_para_jaccard <- compute_similarity(Italy2_mgs, list_spearman_para, method = "jaccard")
sparcc_para_jaccard <- compute_similarity(Italy2_mgs, list_sparcc_para, method = "jaccard")

# %%
all_result_para <- rbind(
    result_to_df(fastcclasso_para_spearman, "fastqcclasso","Spearman"),
    result_to_df(genie3_para_spearman, "genie3","Spearman"),
    result_to_df(fastcclasso_para_jaccard, "fastqcclasso","jaccard"),
    result_to_df(genie3_para_jaccard, "genie3","jaccard"),
    result_to_df(spearman_para_spearman,"spearman","Spearman"),
    result_to_df(sparcc_para_spearman,"sparcc","Spearman"),
    result_to_df(spearman_para_jaccard,"spearman","jaccard"),
    result_to_df(sparcc_para_jaccard,"sparcc","jaccard")
)

ggplot(subset(all_result_para, method == "Spearman"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) + 
  facet_wrap(~ dataset) + 
  labs(x = NULL, y = "Spearman Correlation") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
    axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank(),     
  )


  ggplot(subset(all_result_para, method == "jaccard"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) + 
  facet_wrap(~ dataset) + 
  labs(x = NULL, y = "jaccard index") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
    axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank(),     
  )
# Out:
# plot without title
# plot without title

# %%
# compare different method
list_all_methods <- list(
    fastcclasso = fastcclasso_90,
    spieceasi = spieceasi,
    genie3 = genie3_90,
    spearman = spearman_80,
    sparcc = sparcc_70,
    original_SSMS = Italy2_ssms
)

all_methods_spearman <- compute_similarity(Italy2_mgs,list_all_methods, method = "spearman")
all_methods_jaccard <- compute_similarity(Italy2_mgs,list_all_methods, method = "jaccard")

all_methods <- rbind(
    result_to_df(all_methods_spearman, "all","Spearman"),
    result_to_df(all_methods_jaccard, "all","Jaccard")
)

ggplot(subset(all_methods, method == "Spearman"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Spearman Correlation") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank(),     
  )

# boxplot - Jaccard
ggplot(subset(all_methods, method == "Jaccard"),     
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Jaccard Index") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank(),     
  )
# Out:
# plot without title
# plot without title

# %%
# heatmap of top 1500 abundant features - abundance
#mgs
#ssms
#imputed ssms
library(ComplexHeatmap)
blues <- colorRampPalette(c("white", "#d0e4f5", "#6497b1", "#005b96"))(100)

Austria_mgs_sorted <- Austria_mgs[order(rowSums(Austria_mgs), decreasing = TRUE), ]
Austria_ssms_sorted <- Austria_ssms[order(rowSums(Austria_ssms), decreasing = TRUE), ]
Italy1_mgs_sorted <- Italy1_mgs[order(rowSums(Italy1_mgs), decreasing = TRUE), ]
Italy1_ssms_sorted <- Italy1_ssms[order(rowSums(Italy1_ssms), decreasing = TRUE), ]
Italy2_mgs_sorted <- Italy2_mgs[order(rowSums(Italy2_mgs), decreasing = TRUE), ]
Italy2_ssms_sorted <- Italy2_ssms[order(rowSums(Italy2_ssms), decreasing = TRUE), ]


dim(Italy2_mgs_sorted)
dim(Italy2_ssms_sorted)

norm_ssms <- t(apply(as.matrix(Italy2_ssms_sorted[c(1:1500), ]), 1, function(x) {
  (x - min(x)) / (max(x) - min(x))
}))

norm_mgs <- t(apply(as.matrix(Italy2_mgs_sorted[c(1:1500), ]), 1, function(x) {
  (x - min(x)) / (max(x) - min(x))
}))

color_palette <- colorRampPalette(c("blue", "white", "red"))(100)
pheatmap(norm_mgs,   
        cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "MGS"
)
# Out:
# [1] 2637   58
# [1] 2637   58
# plot without title

# %%
# heatmap of top 1500 abundant features - binery existence
#mgs
#ssms
#imputed ssms
library(ComplexHeatmap)
library(grid)
blues <- colorRampPalette(c("white", "#d0e4f5", "#6497b1", "#005b96"))(100)

binery_Italy2_mgs <- ifelse(Italy2_mgs_sorted[c(1:1500), ] > 0, 1, 0)
binery_Italy2_ssms <- ifelse(Italy2_ssms_sorted[c(1:1500), ] > 0, 1, 0)
binery_Italy1_mgs <- ifelse(Italy1_mgs_sorted[c(1:1500), ] > 0, 1, 0)
binery_Italy1_ssms <- ifelse(Italy1_ssms_sorted[c(1:1500), ] > 0, 1, 0)
binery_Austria_mgs <- ifelse(Austria_mgs_sorted[c(1:1500), ] > 0, 1, 0)
binery_Austria_ssms <- ifelse(Austria_ssms_sorted[c(1:1500), ] > 0, 1, 0)

plot_heatmap <- function(binery_data, title) {
  pheatmap(binery_data,   
        cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = colorRampPalette(c("blue", "red"))(100),
         main = title,
         legend = FALSE
)
}

Italy2_mgs <- plot_heatmap(binery_Italy2_mgs, "")
Italy1_mgs <- plot_heatmap(binery_Italy1_mgs, "")
Austria_mgs <- plot_heatmap(binery_Austria_mgs, "")

Italy2_ssms <- plot_heatmap(binery_Italy2_ssms, "")
Italy1_ssms <- plot_heatmap(binery_Italy1_ssms, "")
Austria_ssms <- plot_heatmap(binery_Austria_ssms, "")

#grid.newpage()
#draw(Italy2_mgs)
#grid.newpage()
#draw(Italy2_ssms)
#grid.newpage()
#draw(Italy1_mgs)
#grid.newpage()
#draw(Italy1_ssms)
#grid.newpage()
#draw(Austria_mgs)
#grid.newpage()
#draw(Austria_ssms)

library(patchwork)
library(cowplot)

g1 <- grid.grabExpr(draw(Italy2_mgs))
g2 <- grid.grabExpr(draw(Italy2_ssms))
g3 <- grid.grabExpr(draw(Italy1_mgs))
g4 <- grid.grabExpr(draw(Italy1_ssms))
g5 <- grid.grabExpr(draw(Austria_mgs))
g6 <- grid.grabExpr(draw(Austria_ssms))

# 
top_row <- plot_grid(g3, g1, g5, ncol = 3)
bottom_row <- plot_grid(g4, g2, g6, ncol = 3)

plot_grid(
  top_row,
  ggdraw() + theme_void(),  # 
  bottom_row,
  ncol = 1,
  rel_heights = c(1, 0.2, 1)  # 
)
# Out:
# plot without title
# plot without title

# %%
pheatmap(norm_ssms,   
        cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "SSMS"
)
# Out:
# plot without title

# %%
# binarize
color_palette <- colorRampPalette(c("blue", "white", "red"))(100)
heatmap_mgs <- ifelse(Italy2_mgs_sorted > 0, 1, 0)
heatmap_ssms <- ifelse(Italy2_ssms_sorted > 0, 1, 0)

pheatmap(as.matrix(heatmap_mgs)[c(1:2000),],
        cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "MGS"
)

# %%
pheatmap(as.matrix(heatmap_ssms)[c(1:2000),],
 cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "SSMS"
)

# %%
# imputed

cclasso_Italy2_ssms_sorted <- list_all_methods$fastcclasso[order(rowSums(list_all_methods$fastcclasso), decreasing = TRUE), ]
sparcc_Italy2_ssms_sorted <- list_all_methods$sparcc[order(rowSums(list_all_methods$sparcc), decreasing = TRUE), ]
spearman_Italy2_ssms_sorted <- list_all_methods$spearman[order(rowSums(list_all_methods$spearman), decreasing = TRUE), ]
spieceasi_Italy2_ssms_sorted <- list_all_methods$spieceasi[order(rowSums(list_all_methods$spieceasi), decreasing = TRUE), ]
genie3_Italy2_ssms_sorted <- list_all_methods$genie3[order(rowSums(list_all_methods$genie3), decreasing = TRUE), ]

heatmap_cclasso <- ifelse(cclasso_Italy2_ssms_sorted > 0, 1, 0)
heatmap_sparcc <- ifelse(sparcc_Italy2_mgs_sorted > 0, 1, 0)
heatmap_genie3 <- ifelse(genie3_Italy2_mgs_sorted > 0, 1, 0)
heatmap_spearman <- ifelse(spearman_Italy2_mgs_sorted > 0, 1, 0)
heatmap_spieceasi <- ifelse(spieceasi_Italy2_mgs_sorted > 0, 1, 0)

# %%
pheatmap(as.matrix(heatmap_cclasso)[c(1:2000),],
 cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "cclasso"
)

# %%
pheatmap(as.matrix(heatmap_sparcc)[c(1:2000),],
 cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "sparcc"
)

# %%
pheatmap(as.matrix(heatmap_spearman)[c(1:2000),],
 cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "spearman"
)
# Out:
# Error in pheatmap(as.matrix(heatmap_spearman)[c(1:2000), ], cluster_rows = FALSE, : konnte Funktion "pheatmap" nicht finden
# Traceback:

# %%
pheatmap(as.matrix(heatmap_spieceasi)[c(1:2000),],
 cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "spieceasi"
)

# %%
pheatmap(as.matrix(heatmap_genie3)[c(1:2000),],
 cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "genie3"
)

# %%
source("utilities.R")
# compare different method -- among those imputed most frequently EC
#imputed_only_ec <- rownames(Italy2_ssms_sorted[c(1000:nrow(Italy2_ssms_sorted)),])
imputed_only_ec <- rownames(Italy2_ssms_sorted[c(1000:1500),])

fastcclasso_90_sub <- fastcclasso_90[rownames(fastcclasso_90) %in% imputed_only_ec,]
fastcclasso_90_sub <- fastcclasso_90_sub[imputed_only_ec,]

spieceasi_sub <- spieceasi[rownames(spieceasi) %in% imputed_only_ec,]
spieceasi_sub <- spieceasi_sub[imputed_only_ec,]

genie3_90_sub <- genie3_90[rownames(genie3_90) %in% imputed_only_ec,]
genie3_90_sub <- genie3_90_sub[imputed_only_ec,]

spearman_80_sub <- spearman_80[rownames(spearman_80) %in% imputed_only_ec,]
spearman_80_sub <- spearman_80_sub[imputed_only_ec,]

sparcc_70_sub <- sparcc_70[rownames(sparcc_70) %in% imputed_only_ec,]
sparcc_70_sub <- sparcc_70_sub[imputed_only_ec,]

Italy2_ssms_sub <- Italy2_ssms_sorted[rownames(Italy2_ssms_sorted) %in% imputed_only_ec,]
Italy2_ssms_sub <- Italy2_ssms_sub[imputed_only_ec,]

Italy2_mgs_sub <- Italy2_mgs_sorted[rownames(Italy2_mgs_sorted) %in% imputed_only_ec,]
Italy2_mgs_sub <- Italy2_mgs_sub[imputed_only_ec,]

list_all_methods <- list(
    fastcclasso = fastcclasso_90_sub,
    spieceasi = spieceasi_sub,
    genie3 = genie3_90_sub,
    spearman = spearman_80_sub,
    sparcc = sparcc_70_sub,
    original_SSMS = Italy2_ssms_sub
)

all_methods_spearman <- compute_similarity_new(Italy2_mgs_sub,list_all_methods, method = "spearman")
all_methods_jaccard <- compute_similarity_new(Italy2_mgs_sub,list_all_methods, method = "jaccard")

all_methods <- rbind(
    result_to_df(all_methods_spearman, "all","Spearman"),
    result_to_df(all_methods_jaccard, "all","Jaccard")
)

ggplot(subset(all_methods, method == "Spearman"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Spearman Correlation") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )


  ggplot(subset(all_methods, method == "Jaccard"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Jaccard index") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )

# %%
#
# load metadata
# metadata
Italy1_curatedmetagenomics_metadata <- read.delim('/Users/zihuahuang/Documents/SSMS/data/metadata/Italy1_metadata.tsv')
Italy1_filereport_read_run <- read.delim('/Users/zihuahuang/Documents/SSMS/data/metadata/Itay1_Italy2_PRJNA447983_tsv.txt')
Italy1_metadata <- merge(x = Italy1_curatedmetagenomics_metadata,
                         y = Italy1_filereport_read_run,
                         by.x = 'subject_id',
                         by.y = 'sample_alias',
                         all.x = TRUE)
Italy2_curatedmetagenomics_metadata <- read.csv('/Users/zihuahuang/Documents/SSMS/data/metadata/Italy2_metadata.csv')
Italy2_metadata <- merge(x = Italy2_curatedmetagenomics_metadata,
                         y = Italy1_filereport_read_run,
                         by.x = 'subject_id',
                         by.y = 'sample_alias',
                         all.x = TRUE)

Austria_metadata <- read.delim('/Users/zihuahuang/Documents/SSMS/data/metadata/Austria_metadata.tsv')

#

# %%
residule_mgs_imputedssms <- t(scale(t(Italy2_mgs_sub))) - t(scale(t(spieceasi_sub)))
pheatmap(residule_mgs_imputedssms,
 #cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "z-score residule_mgs_imputedssms"
)
# Out:
# Error: Objekt 'Italy2_mgs_sub' nicht gefunden
# Traceback:
#
# 1. scale(t(Italy2_mgs_sub))
# 2. t(Italy2_mgs_sub)
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "Objekt 'Italy2_mgs_sub' nicht gefunden", base::quote(eval(expr,
#  .     envir)))

# %%
#grid
source("utilities.R")
# load data

Austriaasref_Italy1_file_paths <- list.files(path = "data/imputed_ec/method_test/Italy1", pattern = "Austria.*\\.csv$", full.names = TRUE)
Austriaasref_Italy2_file_paths <- list.files(path = "data/imputed_ec/method_test/Italy2", pattern = "Austria.*\\.csv$", full.names = TRUE)
Italy1asref_Italy2_file_paths <- list.files(path = "data/imputed_ec/method_test/Italy2", pattern ="Italy1.*\\.csv$", full.names = TRUE)
Italy1asref_Austria_file_paths <- list.files(path = "data/imputed_ec/method_test/Austria", pattern = "Italy1.*\\.csv$", full.names = TRUE)
Italy2asref_Italy1_file_paths <- list.files(path = "data/imputed_ec/method_test/Italy1", pattern = "Italy2.*\\.csv$", full.names = TRUE)
Italy2asref_Austria_file_paths <- list.files(path = "data/imputed_ec/method_test/Austria", pattern ="Italy2.*\\.csv$", full.names = TRUE)

Austriaasref_Italy1_list <- setNames(lapply(Austriaasref_Italy1_file_paths, function(path) {
  read.csv(path, row.names = 1, sep = "\t")
}), basename(Austriaasref_Italy1_file_paths))
Austriaasref_Italy1_list <- lapply(Austriaasref_Italy1_list, function(df) df[order(rownames(df)), ])

#
Austriaasref_Italy2_list <- setNames(lapply(Austriaasref_Italy2_file_paths, function(path) {
  read.csv(path, row.names = 1, sep = "\t")
}),basename(Austriaasref_Italy2_file_paths))
Austriaasref_Italy2_list <- lapply(Austriaasref_Italy2_list, function(df) df[order(rownames(df)), ])
#
Italy1asref_Italy2_list <- setNames(lapply(Italy1asref_Italy2_file_paths,function(path) {
  read.csv(path, row.names = 1, sep = "\t")
}),basename(Italy1asref_Italy2_file_paths))
Italy1asref_Italy2_list <- lapply(Italy1asref_Italy2_list, function(df) df[order(rownames(df)), ])
#
Italy1asref_Austria_list <- setNames(lapply(Italy1asref_Austria_file_paths, function(path) {
  read.csv(path, row.names = 1, sep = "\t")
}),basename(Italy1asref_Austria_file_paths))
Italy1asref_Austria_list <- lapply(Italy1asref_Austria_list, function(df) df[order(rownames(df)), ])
#
Italy2asref_Italy1_list <- setNames(lapply(Italy2asref_Italy1_file_paths, function(path) {
  read.csv(path, row.names = 1, sep = "\t")
}),basename(Italy2asref_Italy1_file_paths))
Italy2asref_Italy1_list <- lapply(Italy2asref_Italy1_list, function(df) df[order(rownames(df)), ])
#
Italy2asref_Austria_list <- setNames(lapply(Italy2asref_Austria_file_paths, function(path) {
  read.csv(path, row.names = 1, sep = "\t")
}),basename(Italy2asref_Austria_file_paths))
Italy2asref_Austria_list <- lapply(Italy2asref_Austria_list, function(df) df[order(rownames(df)), ])

# %%
# compute
Austriaasref_Italy1_all_methods <- list(
    original_SSMS = Italy1_ssms,
    fastcclasso = Austriaasref_Italy1_list$predicted_level4ec_fastcclasso_Austriaasref_Italy1.csv,
    spieceasi = Austriaasref_Italy1_list$predicted_level4ec_spiec_Austriaasref_Italy1.csv,
    genie3 = Austriaasref_Italy1_list$predicted_level4ec_genie3_Austriaasref_Italy1.csv,
    spearman = Austriaasref_Italy1_list$predicted_level4ec_spearman_Austriaasref_Italy1.csv,
    sparcc = Austriaasref_Italy1_list$predicted_level4ec_sparcc_Austriaasref_Italy1.csv
)

Austriaasref_Italy2_all_methods <- list(
    original_SSMS = Italy2_ssms,
    fastcclasso = Austriaasref_Italy2_list$predicted_level4ec_fastcclasso_Austriaasref_Italy2.csv,
    spieceasi = Austriaasref_Italy2_list$predicted_level4ec_spiec_Austriaasref_Italy2.csv,
    genie3 = Austriaasref_Italy2_list$predicted_level4ec_genie3_Austriaasref_Italy2.csv,
    spearman = Austriaasref_Italy2_list$predicted_level4ec_spearman_Austriaasref_Italy2.csv,
    sparcc = Austriaasref_Italy2_list$predicted_level4ec_sparcc_Austriaasref_Italy2.csv
)

Italy1asref_Italy2_all_methods <- list(
    original_SSMS = Italy2_ssms,
    fastcclasso = Italy1asref_Italy2_list$predicted_level4ec_fastcclasso_Italy1asref_Italy2.csv,
    spieceasi = Italy1asref_Italy2_list$predicted_level4ec_spiec_Italy1asref_Italy2.csv,
    genie3 = Italy1asref_Italy2_list$predicted_level4ec_genie3_Italy1asref_Italy2.csv,
    spearman = Italy1asref_Italy2_list$predicted_level4ec_spearman_Italy1asref_Italy2.csv,
    sparcc = Italy1asref_Italy2_list$predicted_level4ec_sparcc_Italy1asref_Italy2.csv 
)

Italy1asref_Austria_all_methods <- list(
  original_SSMS = Austria_ssms,
  fastcclasso = Italy1asref_Austria_list$predicted_level4ec_fastcclasso_Italy1asref_Austria.csv,
  spieceasi = Italy1asref_Austria_list$predicted_level4ec_spiec_Italy1asref_Austria.csv,
  genie3 = Italy1asref_Austria_list$predicted_level4ec_genie3_Italy1asref_Austria.csv,
  spearman = Italy1asref_Austria_list$predicted_level4ec_spearman_Italy1asref_Austria.csv,
  sparcc = Italy1asref_Austria_list$predicted_level4ec_sparcc_Italy1asref_Austria.csv 
)

Italy2asref_Austria_all_methods <- list(
  original_SSMS = Austria_ssms,
  fastcclasso = Italy2asref_Austria_list$predicted_level4ec_fastcclasso_Italy2asref_Austria.csv,
  spieceasi = Italy2asref_Austria_list$predicted_level4ec_spiec_Italy2asref_Austria.csv,
  genie3 = Italy2asref_Austria_list$predicted_level4ec_genie3_Italy2asref_Austria.csv,
  spearman = Italy2asref_Austria_list$predicted_level4ec_spearman_Italy2asref_Austria.csv,
  sparcc = Italy2asref_Austria_list$predicted_level4ec_sparcc_Italy2asref_Austria.csv 
)

Italy2asref_Italy1_all_methods <- list(
  original_SSMS = Italy1_ssms,
  fastcclasso = Italy2asref_Italy1_list$predicted_level4ec_fastcclasso_Italy2asref_Italy1.csv,
  spieceasi = Italy2asref_Italy1_list$predicted_level4ec_spiec_Italy2asref_Italy1.csv,
  genie3 = Italy2asref_Italy1_list$predicted_level4ec_genie3_Italy2asref_Italy1.csv,
  spearman = Italy2asref_Italy1_list$predicted_level4ec_spearman_Italy2asref_Italy1.csv,
  sparcc = Italy2asref_Italy1_list$predicted_level4ec_sparcc_Italy2asref_Italy1.csv
)

# %%
# compute similarity
Austriaasref_Italy1_all_methods_all_methods_spearman <- compute_similarity(Italy1_mgs,Austriaasref_Italy1_all_methods, method = "spearman")
Austriaasref_Italy1_all_methods_all_methods_jaccard <- compute_similarity(Italy1_mgs,Austriaasref_Italy1_all_methods, method = "jaccard")

Austriaasref_Italy2_all_methods_all_methods_spearman <- compute_similarity(Italy2_mgs,Austriaasref_Italy2_all_methods, method = "spearman")
Austriaasref_Italy2_all_methods_all_methods_jaccard <- compute_similarity(Italy2_mgs,Austriaasref_Italy2_all_methods, method = "jaccard")

Italy1asref_Italy2_all_methods_all_methods_spearman <- compute_similarity(Italy2_mgs,Italy1asref_Italy2_all_methods, method = "spearman")
Italy1asref_Italy2_all_methods_all_methods_jaccard <- compute_similarity(Italy2_mgs,Italy1asref_Italy2_all_methods, method = "jaccard")

Italy1asref_Austria_all_methods_all_methods_spearman <- compute_similarity(Austria_mgs,Italy1asref_Austria_all_methods, method = "spearman")
Italy1asref_Austria_all_methods_all_methods_jaccard <- compute_similarity(Austria_mgs,Italy1asref_Austria_all_methods, method = "jaccard")

Italy2asref_Austria_all_methods_all_methods_spearman <- compute_similarity(Austria_mgs,Italy2asref_Austria_all_methods, method = "spearman")
Italy2asref_Austria_all_methods_all_methods_jaccard <- compute_similarity(Austria_mgs,Italy2asref_Austria_all_methods, method = "jaccard")

Italy2asref_Italy1_all_methods_all_methods_spearman <- compute_similarity(Italy1_mgs,Italy2asref_Italy1_all_methods, method = "spearman")
Italy2asref_Italy1_all_methods_all_methods_jaccard <- compute_similarity(Italy1_mgs,Italy2asref_Italy1_all_methods, method = "jaccard")


combo_all_methods <- rbind(
    result_to_df(Austriaasref_Italy1_all_methods_all_methods_spearman, "Austriaasref_Italy1","Spearman"),
    result_to_df(Austriaasref_Italy1_all_methods_all_methods_jaccard, "Austriaasref_Italy1","Jaccard"),

    result_to_df(Austriaasref_Italy2_all_methods_all_methods_spearman, "Austriaasref_Italy2","Spearman"),
    result_to_df(Austriaasref_Italy2_all_methods_all_methods_jaccard, "Austriaasref_Italy2","Jaccard"),

    result_to_df(Italy1asref_Italy2_all_methods_all_methods_spearman, "Italy1asref_Italy2","Spearman"),
    result_to_df(Italy1asref_Italy2_all_methods_all_methods_jaccard, "Italy1asref_Italy2","Jaccard"),

    result_to_df(Italy1asref_Austria_all_methods_all_methods_spearman, "Italy1asref_Austria","Spearman"),
    result_to_df(Italy1asref_Austria_all_methods_all_methods_jaccard, "Italy1asref_Austria","Jaccard"),

    result_to_df(Italy2asref_Austria_all_methods_all_methods_spearman, "Italy2asref_Austria","Spearman"),
    result_to_df(Italy2asref_Austria_all_methods_all_methods_jaccard, "Italy2asref_Austria","Jaccard"),

    result_to_df(Italy2asref_Italy1_all_methods_all_methods_spearman, "Italy2asref_Italy1","Spearman"),
    result_to_df(Italy2asref_Italy1_all_methods_all_methods_jaccard, "Italy2asref_Italy1","Jaccard")

)

order_vec <- c("original_SSMS", "fastcclasso", "genie3", "sparcc", "spearman", "spieceasi")
combo_all_methods$group <- factor(combo_all_methods$group, levels = order_vec)


ggplot(subset(combo_all_methods, dataset == "Austriaasref_Italy1" & method == "Spearman"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Spearman Correlation") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )



  ggplot(subset(combo_all_methods, dataset == "Austriaasref_Italy2" & method == "Spearman"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Spearman Correlation") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )
  ggplot(subset(combo_all_methods, dataset == "Italy2asref_Italy1" & method == "Spearman"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Spearman Correlation") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )
  ggplot(subset(combo_all_methods, dataset == "Italy2asref_Austria" & method == "Spearman"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Spearman Correlation") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )
  ggplot(subset(combo_all_methods, dataset == "Italy1asref_Italy2" & method == "Spearman"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Spearman Correlation") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )

    ggplot(subset(combo_all_methods, dataset == "Italy1asref_Austria" & method == "Spearman"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Spearman Correlation") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
     axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )

  ggplot(subset(combo_all_methods, dataset == "Austriaasref_Italy1" & method == "Jaccard"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Jaccard Index") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
    axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )



ggplot(subset(combo_all_methods, dataset == "Austriaasref_Italy2" & method == "Jaccard"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Jaccard Index") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
    axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )
ggplot(subset(combo_all_methods, dataset == "Italy2asref_Italy1" & method == "Jaccard"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Jaccard Index") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
    axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )
ggplot(subset(combo_all_methods, dataset == "Italy2asref_Austria" & method == "Jaccard"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Jaccard Index") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
    axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )
ggplot(subset(combo_all_methods, dataset == "Italy1asref_Italy2" & method == "Jaccard"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Jaccard Index") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
    axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )

ggplot(subset(combo_all_methods, dataset == "Italy1asref_Austria" & method == "Jaccard"), 
       aes(x = dataset, y = similarity, fill = group)) +
  geom_boxplot(color = "black", size = 0.6) +  
  labs(x = "",
       y = "Jaccard Index") +
  theme_minimal() +
  theme(
    panel.grid = element_blank(),         
    panel.background = element_blank(),   
    plot.background = element_blank(),
    axis.line = element_line(color = "black"),
    axis.text = element_text(size = 15, color = "black"),
    axis.title = element_text(size = 15, color = "black"),
    legend.title = element_text(size = 14),
    legend.text = element_text(size = 14),
    axis.title.x = element_blank(),    
    axis.text.x = element_blank(),     
    axis.ticks.x = element_blank() 
  )

# %%
# compare z score
source("utilities.R")
# compare different method -- among those imputed most frequently EC
#imputed_only_ec <- rownames(Italy2_ssms_sorted[c(1000:nrow(Italy2_ssms_sorted)),])
imputed_only_ec <- rownames(Italy2_ssms_sorted[c(1000:1500),])

fastcclasso_90_sub <- fastcclasso_90[rownames(fastcclasso_90) %in% imputed_only_ec,]
fastcclasso_90_sub <- fastcclasso_90_sub[imputed_only_ec,]

spieceasi_sub <- spieceasi[rownames(spieceasi) %in% imputed_only_ec,]
spieceasi_sub <- spieceasi_sub[imputed_only_ec,]

genie3_90_sub <- genie3_90[rownames(genie3_90) %in% imputed_only_ec,]
genie3_90_sub <- genie3_90_sub[imputed_only_ec,]

spearman_80_sub <- spearman_80[rownames(spearman_80) %in% imputed_only_ec,]
spearman_80_sub <- spearman_80_sub[imputed_only_ec,]

sparcc_70_sub <- sparcc_70[rownames(sparcc_70) %in% imputed_only_ec,]
sparcc_70_sub <- sparcc_70_sub[imputed_only_ec,]

Italy2_ssms_sub <- Italy2_ssms_sorted[rownames(Italy2_ssms_sorted) %in% imputed_only_ec,]
Italy2_ssms_sub <- Italy2_ssms_sub[imputed_only_ec,]

Italy2_mgs_sub <- Italy2_mgs_sorted[rownames(Italy2_mgs_sorted) %in% imputed_only_ec,]
Italy2_mgs_sub <- Italy2_mgs_sub[imputed_only_ec,]

list_all_methods <- list(
    fastcclasso = fastcclasso_90_sub,
    spieceasi = spieceasi_sub,
    genie3 = genie3_90_sub,
    spearman = spearman_80_sub,
    sparcc = sparcc_70_sub,
    original_SSMS = Italy2_ssms_sub
)

scarlet_z_socre <- data.frame(
    "mgs" = as.vector(t(scale(t(Italy2_mgs_sub)))),
    "ssms" = as.vector(t(scale(t(Italy2_ssms_sub)))),
    "imputed_ssms" = as.vector(t(scale(t(spieceasi_sub))))
)


library(tidyr)
library(ggplot2)

# 
scarlet_z_socre_long <- pivot_longer(scarlet_z_socre, cols = c(ssms, imputed_ssms), 
                        names_to = "type", values_to = "x_value")

ggplot(scarlet_z_socre, aes(x = ssms, y = mgs)) +
  geom_point(alpha = 0.5) +
  geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "red") +
  labs(x = "ssms",
       y = "mgs",
       title = "ssms vs mgs") +
  theme_minimal()

ggplot(scarlet_z_socre, aes(x = imputed_ssms, y = mgs)) +
  geom_point(alpha = 0.5) +
  geom_abline(slope = 1, intercept = 0, linetype = "dashed", color = "red") +
  labs(x = "ssms",
       y = "mgs",
       title = "imputed ssms vs mgs") +
  theme_minimal()

ggplot(scarlet_z_socre_long, aes(x = x_value, y = mgs, shape = type, color = type)) +
  geom_point(alpha = 0.5) +
  scale_shape_manual(values = c(16, 17)) +  # 设置形状：圆/三角等
  theme_minimal() +
  labs(x = "SSMs (Raw or Imputed)",
       y = "MGS",
       title = "MGS vs SSMs/Imputed SSMs")

# residule visulization
residule_mgs_ssms <- t(scale(t(Italy2_mgs_sub))) - t(scale(t(Italy2_ssms_sub)))
pheatmap(residule_mgs_ssms,
 
 #cluster_rows = FALSE,
         show_rownames = FALSE,
        show_colnames = FALSE,
         color = color_palette,
         main = "z-score residule_mgs_ssms"
)
